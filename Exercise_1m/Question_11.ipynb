# %% [markdown]
# # Question Eleven

# %%
import stemgraphic

stem_data = [360, 445, 403, 376, 434, 402, 397, 425, 407, 369,
            462, 399, 427, 420, 410, 391, 430, 369, 410, 397]

stemgraphic.stem_graphic(stem_data, scale=10)
# Out:
# (<Figure size 750x350 with 1 Axes>, <Axes: >)

# %%
new = [360, 445, 403, 376, 434, 402, 397, 425, 407, 369,
       462, 399, 427, 420, 410, 391, 430, 369, 410, 397]

old = [321, 325, 345, 349, 350, 356, 356, 360, 361, 366,
      371, 372, 372, 373, 380, 386, 399, 402, 421, 423]

data = [new, old]

import seaborn as sns

sns.boxplot(data, orient='h', whis=462)
# Out:
# <Axes: >

# %% [markdown]
# The average weight value for the chicks on the new strain of corn is much higher. The majority of the chicks fed with the new strain of corn have a higher weight that the control group.
