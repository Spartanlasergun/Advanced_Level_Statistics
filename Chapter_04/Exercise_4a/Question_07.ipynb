# %% [markdown]
# # Question 7
# -----

# %% [markdown]
# $$p.d.f = c(3 - r)$$
#
# $$c(3 - 0) + c(3 - 1) + c(3 - 2)+ c(3 - 3) = 1$$
#
# $$3c + 2c + c = 1$$
#
# $$6c = 1$$
#
# $$c = \frac{1}{6}$$

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3]
y = [(1/2), (1/3), (1/6), 0]

plt.bar(x, y, width=0.1)
plt.show()

# %% [markdown]
# $$P(1 \le R < 3) = \frac{1}{3} + \frac{1}{6} = \frac{1}{2}$$
