# %% [markdown]
# # Question 1
# -----

# %%
a = 1 - (0.2 + 0.25 + 0.4 + 0.05)
print("a = " + str(a))
# Out:
# a = 0.09999999999999987

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [0.2, 0.25, 0.4, 0.1, 0.05]

plt.bar(x, y, width=0.1)
plt.show()

# %% [markdown]
# b)
# (i) $$P(1 \le X \le 3) = 0.2 + 0.25 + 0.4 = 0.85$$
#
# (ii) $$P(X >2) = 0.4 + 0.1 + 0.05 = 0.55$$
#
# (iii) $$P(2 \le X < 5) = 0.4 + 0.1 = 0.5$$
#
# (iv) mode = 3
