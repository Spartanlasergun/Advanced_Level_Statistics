# %% [markdown]
# # Question 2
# -----

# %%
import matplotlib.pyplot as plt

x = [-2, -1, 0, 1, 2, 3]
y = x

plt.plot(x, y, linestyle="--")
plt.show()

# %% [markdown]
# b)
# $$\int_{-2}^{3} k = 1$$
#
# $$[kx]_{-2}^{3} = 1$$
#
# $$3k - (-2k) = 1$$
#
# $$5k = 1$$
#
# $$k = \frac{1}{5}$$
#
# c)
# $$P(-1.6 \le X \le 2.1) = \int_{-1.6}^{2.1} 0.2$$
#
# $$[0.2x]_{-1.6}^{2.1}$$
#
# $$0.42 - (-0.32) = 0.74$$
