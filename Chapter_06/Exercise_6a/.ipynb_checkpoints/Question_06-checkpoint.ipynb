# %% [markdown]
# # Question 6
# -----

# %% [markdown]
# a)
# $$f(x) = kx$$
#
# $$\int_{0}^{4} kx = 1$$
#
# $$[\frac{kx^2}{2}]_{0}^{4} = 1$$
#
# $$8k = 1$$
#
# $$k = \frac{1}{8}$$

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [(1/8), (2/8), (3/8), (4/8)]

plt.plot(x, y, linestyle="--")
plt.show()

# %% [markdown]
# $$P(1 \le X \le 2.5) = \int_{1}^{2.5} \frac{1}{8}x$$
#
# $$P(1 \le X \le 2.5) = [\frac{x^2}{16}]_{1}^{2.5}$$
#
# $$P(1 \le X \le 2.5) = 0.390625 - 0.0625$$
#
# $$P(1 \le X \le 2.5) = 0.328125$$
