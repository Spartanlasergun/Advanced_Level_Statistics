# %% [markdown]
# # Question 3
# -----

# %% [markdown]
# a)
#
# $$0.5 * A * 3 = 1$$
#
# $$1.5A  = 1$$
#
# $$A = \frac{2}{3}$$
#
# -----
# b)
# $$ m = \frac{0.666 - 0}{1 - 0}$$
#
# $$m = \frac{2}{3}$$
#
# $$f(x) = \frac{2x}{3}, \ \ \ for \ \ 0 \le x \le 1$$
#
# $$m = \frac{0.6666 - 0}{1 - 3}$$
#
# $$m = \frac{-1}{3}$$
#
# $$\frac{2}{3} = \frac{-1}{3} + C$$
#
# $$C = 1$$
#
# $$f(x) = 1 - \frac{x}{3}, \ \ \ for \ \ 1 \le x \le 3$$
#
# $$E(X) = \int_{0}^{1} frac{2x^2}{3} \ dx + \int_{1}^{3} x - \frac{x^2}{3} \ dx$$
#
# $$E(X) = [\frac{2x^3}{9}]_{0}^{1} + [0.5x^2 - \frac{x^3}{9}]_{1}^{3}$$
#
# $$E(X) = \frac{2}{9} + (1.5 - 0.388889)$$
#
# $$E(X) = 1.3333$$
#
# $$E(X^2) = \int_{0}^{1} frac{2x^3}{3} \ dx + \int_{1}^{3} x^2 - \frac{x^3}{3} \ dx$$
#
# $$E(X^2) = [\frac{x^4}{6}]_{0}^{1} + [\frac{x^3}{3} - \frac{x^4}{12}]_{1}^{3}$$
#
# $$E(X^2) = \frac{1}{6} + ((9 - 6.75) - (\frac{1}{3} - \frac{1}{12}))$$
#
# $$E(X^2) = 2.166666$$
#
# $$Var(X) = 2.16666 - (1.33333^2)$$
#
# $$Var(X) = 0.389$$
#
# -----
# c)
#
# $$\frac{x^2}{3} = 0.5$$
#
# $$x^2 = 1.5$$
#
# $$x = 1.22$$
#
# $$median = 1.22$$
#
# -----
# $$P(X > 1.22) = \int_{1.22}^{3} 1 - \frac{x}{3} \ dx$$
#
# $$P(X > 1.22) = [x - \frac{x^2}{6}]_{1.22}^{3}$$
#
# $$P(X > 1.22) = (3 - 1.5) - (1.22 - 0.25)$$
#
# $$P(X > 1.22) = 0.53$$
#
# $$A = 0.53$$
#
# $$A' = 0.47$$
#
# $$prob = 1 - (A'^3)$$
#
# $$prob = 1 - 0.47^3$$
#
# $$prob = 0.896$$
