# %% [markdown]
# # Question 12
# -----

# %% [markdown]
# $$f(x) = kax - kx^2$$
#
# $$\int_{0}^{2} kax - kx^2 \ dx = 1$$
#
# $$[\frac{kax^2}{2} - \frac{kx^3}{3}]_{0}^{2} = 1$$
#
# $$2ka - \frac{8k}{3} = 3$$
#
# $$6ka - 8k = 3$$
#
# $$k(6a - 8) = 3$$
#
# $$k = \frac{3}{6a - 8}$$
#
# -----
#
# $$xf(x) = kax^2 - kx^3$$
#
# $$E(X) = \int_{0}^{2} kax^2 - kx^3 \ dx$$
#
# $$E(X) = [\frac{kax^3}{3} - \frac{kx^4}{4}]_{0}^{2}$$
#
# $$E(X) = \frac{8ka}{3} - 4k$$
#
# since E(X) = 1,
#
# $$\frac{8ka}{3} - 4k = 1$$
#
# $$8ka - 12k = 3$$
#
# $$k(8a - 12) = 3$$
#
# $$k = \frac{3}{8a - 12}$$
#
# solving for a,
#
# $$\frac{3}{8a - 12} = \frac{3}{6a - 8}$$
#
# $$3(6a - 8) = 3(8a - 12)$$
#
# $$18a - 24 = 24a - 36$$
#
# $$-6a = -12$$
#
# $$a = 2$$
#
# solving for k,
#
# $$k = \frac{3}{6(2) - 8}$$
#
# $$k = \frac{3}{4}$$

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2.1, 0.1)
y = []
for item in x:
    fx = (0.75 * 2 * item) - (0.75 * pow(item, 2))
    y.append(fx)

plt.plot(x, y)
plt.show()

# %% [markdown]
# $$x^2f(x) = 1.5x^3 - 0.75x^4$$
#
# $$E(X^2) = \int_{0}^{2} 1.5x^3 - 0.75x^4 \ dx$$
#
# $$E(X^2) = [\frac{1.5x^4}{4} - \frac{0.75x^5}{5}]_{0}^{2}$$
#
# $$E(X^2) = 6 - 4.8$$
#
# $$E(X^2) = 1.2$$
#
# $$Var(X) = E(X^2) - (E(X))^2$$
#
# $$Var(X) = 1.2 - 1^2$$
#
# $$Var(X) = 0.2$$
