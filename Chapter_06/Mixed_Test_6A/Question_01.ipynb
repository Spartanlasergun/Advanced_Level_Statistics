# %% [markdown]
# # Question 1
# -----

# %%
import matplotlib.pyplot as plt

x = [68, 38, 46, 40, 50, 45, 60, 144]
y = [40, 105, 150, 195, 245, 305, 360, 600]
raw_data = []
index = 0
for item in x:
    count = item
    while count != 0:
        raw_data.append(y[index])
        count = count - 1
    index = index + 1
plt.hist(raw_data, bins=[0, 80, 130, 170, 220, 270, 320, 400, 800], density=True, edgecolor="black")
plt.show()

# %% [markdown]
# b)
#
# $$\int_{0}^{4} 3k \ dx + \int_{4}^{8} k \ dx = 1$$
#
# $$[3kx]_{0}^{4} + [kx]_{4}^{8} = 1$$
#
# $$12k + (8k - 4k) = 1$$
#
# $$k = \frac{1}{16}$$
#
# -----
# c)
#
# $$P(0 \le X \le 1.3) = \int_{0}^{1.3} \frac{3}{16} \ dx$$
#
# $$P(0 \le X \le 1.3) = [\frac{3x}{16}]_{0}^{1.3}$$
#
# $$P(0 \le X \le 1.3) = 0.24375$$
#
# $$estimate = 0.24375 * 491 = 119.68$$
#
# $$approximately \ 120 \ households$$
#
# -----
# d)
# Since the dataset shows 106 households with this income, the model may be producing an overestimate
