# %% [markdown]
# # Question 1
# -----

# %% [markdown]
# a)
#
# $$f(x) = 0.75(x^2 + 1)$$
#
# $$xf(x) = 0.75x^3 + 0.75x$$
#
# $$E(X) = \int_{0}^{1} 0.75x^3 + 0.75x$$
#
# $$E(X) = [0.1875x^4 + 0.375x^2]_{0}^{1}$$
#
# $$E(X) = 0.5625$$
#
# -----
# b)
#
# $$f(x) = 0.75x(2 - x)$$
#
# $$xf(x) = 1.5x^2 - 0.75x^3$$
#
# $$E(X) = \int_{0}^{2} 1.5x^2 - 0.75x^3$$
#
# $$E(X) = [0.5x^3 - 0.1875x^4]_{0}^{2}$$
#
# $$E(X) = 1$$
#
# -----
# c)
#
# $$f(x) = \frac{1}{18}(6 - x)$$
#
# $$xf(x) = \frac{1}{3}x - \frac{1}{18}x^2$$
#
# $$E(X) = \int_{0}^{6} \frac{1}{3}x - \frac{1}{18}x^2$$
#
# $$E(X) = [\frac{x^2}{6} - \frac{x^3}{54}]_{0}^{6}$$
#
# $$E(X) = 6 - 4$$
#
# $$E(X) = 2$$
#
# -----
# d)
#
# $$f(x) = kx^3$$
#
# $$\int_{0}^{2} kx^3 = 1$$
#
# $$[\frac{kx^4}{4}]_{0}^{2} = 1$$
#
# $$4k = 1$$
#
# $$k = 0.25$$
#
# $$xf(x) = \frac{1}{4}x^4$$
#
# $$E(X) = \int_{0}^{2} \frac{1}{4}x^4$$
#
# $$E(X) = [\frac{x^5}{20}]_{0}^{2}$$
#
# $$E(X) = 1.6$$
#
# -----
# e)
#
# $$f(x) = \frac{3}{8} + \frac{3}{32}x(4 - x)$$
#
# $$xf(x) = \frac{3x}{8} + \frac{3x^2}{32}(4 - x)$$
#
# $$xf(x) = \frac{3x}{8} + \frac{3x^2}{8} - \frac{3x^3}{32}$$
#
# $$E(X) = \int_{\frac{2}{3}}^{2} \frac{3x}{8} + \int_{2}^{4} \frac{3x^2}{8} - \frac{3x^3}{32}$$
#
# $$E(X) = [\frac{3x^2}{16}]_{\frac{2}{3}}^{2} + [\frac{x^3}{8} - \frac{3x^4}{128}]_{2}^{4}$$
#
# $$E(X) = \frac{2}{3} + ((8 - 6) - (1 - 0.375))$$
#
# $$E(X) = \frac{2}{3} + 1.375$$
#
# $$E(X) = 2.042$$
