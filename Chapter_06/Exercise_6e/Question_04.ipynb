# %% [markdown]
# # Question 4
# -----

# %% [markdown]
# a)
#
# $$F(x) = \frac{2x}{3}, \ \ \ for \ \ 0 \le x \le 1$$
#
# $$F(x) = \frac{x}{3} + k, \ \ \ for \ \ 1 \le x \le 2$$
#
# taking the lower boundary at $x = 1, \ \ y = \frac{2}{3}$
#
# $$\frac{2}{3} = \frac{1}{3} + k$$
#
# $$k = \frac{1}{3}$$
#
# -----
# b)
#
# $$p.d.f = \frac{2}{3}, \ \ \ for \ \ 0 \le x \le 1$$
#
# $$p.d.f = \frac{1}{3}, \ \ \ for \ \ 1 \le x \le 2$$

# %%
import matplotlib.pyplot as plt

x = [0, 1]
y = [(2/3), (2/3)]

x_1 = [1, 2]
y_1 = [(1/3), (1/3)]

plt.plot(x, y)
plt.plot(x_1, y_1)
plt.show()

# %% [markdown]
# c)
#
# $$xf(x) = \frac{2x}{3}, \ \ \ for \ \ 0 \le x \le 1$$
#
# $$xf(x) = \frac{x}{3}, \ \ \ for \ \ 1 \le x \le 2$$
#
# $$E(X) = \int_{0}^{1} \frac{2x}{3} \ dx + \int_{1}^{2} \frac{x}{3} \ dx$$
#
# $$E(X) = [\frac{x^2}{3}]_{0}^{1} + [\frac{x^2}{6}]_{1}^{2}$$
#
# $$E(X) = \frac{1}{3} + (\frac{2}{3} - \frac{1}{6}$$
#
# $$E(X) = \frac{5}{6}$$
#
# -----
# d)
#
# $$x^2f(x) = \frac{2x^2}{3}, \ \ \ for \ \ 0 \le x \le 1$$
#
# $$x^2f(x) = \frac{x^2}{3}, \ \ \ for \ \ 1 \le x \le 2$$
#
# $$E(X^2) = \int_{0}^{1} \frac{2x^2}{3} \ dx + \int_{1}^{2} \frac{x^2}{3} \ dx$$
#
# $$E(X^2) = [\frac{2x^3}{9}]_{0}^{1} + [\frac{x^3}{9}]_{1}^{2}$$
#
# $$E(X^2) = \frac{2}{9} + (\frac{8}{9} - \frac{1}{9})$$
#
# $$E(X^2) = 1$$
#
# $$Var(X) = E(X^2) - (E(X))^2$$
#
# $$Var(X) = 1 - (\frac{5}{6})^2$$
#
# $$Var(X) = 0.3056$$
#
# $$\sigma = \sqrt{0.3056}$$
#
# $$\sigma = 0.553$$
