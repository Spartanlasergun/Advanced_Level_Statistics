# %% [markdown]
# # Question 3
# -----

# %% [markdown]
# a)
#
# $$F(x) = x - kx^2$$
#
# $$f(x) = 1 - 2kx$$
#
# $$\int_{0}^{2} 1 - 2kx \ dx = 1$$
#
# $$[x - kx^2]_{0}^{2} = 1$$
#
# $$2 - 4k = 1$$
#
# $$4k = 1$$
#
# $$k = 0.25$$
#
# -----
# b)
#
# $$p.d.f = 1 - 0.5x$$
#
# -----
# c)
#
# $$x - 0.25x^2 = 0.5$$
#
# $$4x - x^2 = 2$$
#
# $$4x - x^2 - 2 = 0$$
#
# $$a = -1, \ \ b = 4, \ \ c = -2$$
#
# $$x = \frac{-4 \pm \sqrt{16 - 4(-1)(-2)}}{-2}$$
#
# $$x = \frac{-4 \pm \sqrt{8}}{-2}$$
#
# $$x = \frac{-4 \pm 2.83}{-2}$$
#
# $$x = 0.585, 3.415$$
#
# Since $0 \le x \le 2$,
#
# $$median = 0.585$$
#
# -----
# d)
#
# $$xf(x) = x - 0.5x^2$$
#
# $$E(X) = [0.5x^2 - \frac{0.5x^3}{3}]_{0}^{2}$$
#
# $$E(X) = 2 - \frac{4}{3}$$
#
# $$E(X) = \frac{2}{3}$$
#
# $$x^2f(x) = x^2 - 0.5x^3$$
#
# $$E(X^2) = \int_{0}^{2} x^2 - 0.5x^3 \ dx$$
#
# $$E(X^2) = [\frac{x^3}{3} - 0.125x^4]_{0}^{2}$$
#
# $$E(X^2) = \frac{8}{3} - 2$$
#
# $$E(X^2) = \frac{2}{3}$$
#
# $$Var(X) = E(X^2) - (E(X))^2$$
#
# $$Var(X) = \frac{2}{3} - (\frac{2}{3})^2$$
#
# $$Var(X) = \frac{2}{9}$$
