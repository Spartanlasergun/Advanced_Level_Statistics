# %% [markdown]
# # Question 10
# -----

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1, 3.1, 0.1)
y = []
for item in x:
    fx = (1 + item) / 6
    y.append(fx)

plt.plot(x, y)
plt.show()

# %% [markdown]
# b)
#
# $$f(x) = \frac{1}{6} + \frac{x}{6}$$
#
# $$xf(x) = \frac{x}{6} + \frac{x^2}{6}$$
#
# $$E(X) = \int_{1}^{3} \frac{x}{6} + \frac{x^2}{6} \ dx$$
#
# $$E(X) = [\frac{x^2}{12} + \frac{x^3}{18}]_{1}^{3}$$
#
# $$E(X) = (0.75 + 1.5) - (\frac{1}{12} + \frac{1}{18})$$
#
# $$E(X) = 2.1111$$
#
# -----
# c)
#
# $$f(x) =  \frac{1}{6} + \frac{x}{6}$$
#
# $$F(x) = \int_{1}^{t}  \frac{1}{6} + \frac{x}{6} \ dx$$
#
# $$F(x) = [\frac{x}{6} + \frac{x^2}{12}]_{1}^{t}$$
#
# $$F(x) = (\frac{t}{6} + \frac{t^2}{12}) - (\frac{1}{6} + \frac{1}{12})$$
#
# $$F(x) = \frac{t^2}{6} + \frac{t}{12} - \frac{1}{4}$$
#
# -----
# d)
#
# for $P(X \le m) = 0.5$,
#
# $$\frac{t^2}{12} + \frac{t}{6} - \frac{1}{4} = 0.5$$
#
# $$t^2 + 2t - 3 = 6$$
#
# $$t^2 + 2t -9 = 0$$
#
# $$a = 1, \ \ b = 2, \ \ c = -9$$
#
# $$m = \frac{-2 \pm \sqrt{4 - (4 * -9)}}{2}$$
#
# $$m = \frac{-2 \pm \sqrt{40}}{2}$$
#
# $$m = 2.16, \ \ -4.16$$
#
# $$thus, m = 2.16$$
