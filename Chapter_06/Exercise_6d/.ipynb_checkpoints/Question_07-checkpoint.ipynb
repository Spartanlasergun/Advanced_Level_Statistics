# %% [markdown]
# # Question 7
# -----

# %% [markdown]
# a)
#
# $$f(x) = kx^2$$
#
# $$\int_{1}^{2} kx^2 \ dx = 1$$
#
# $$[\frac{kx^3}{3}]_{1}^{2} = 1$$
#
# $$\frac{8k}{3} - \frac{k}{3} = 1$$
#
# $$8k - k = 3$$
#
# $$k = \frac{3}{7}$$
#
# -----
# b)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1, 2.1, 0.1)
y = []
for item in x:
    fx = (3/7) * pow(item, 2)
    y.append(fx)

plt.plot(x, y)
plt.show()

# %% [markdown]
# $$xf(x) = \frac{3x^3}{7}$$
#
# $$E(X) = \int_{1}^{2} \frac{3x^3}{7} \ dx$$
#
# $$E(X) = [\frac{3x^4}{28}]_{1}^{2}$$
#
# $$E(X) = 1.607$$
#
# $$x^2f(x) = \frac{3x^4}{7}$$
#
# $$E(X^2) = \int{1}^{2} \frac{3x^4}{7} \ dx$$
#
# $$E(X^2) = [\frac{3x^5}{35}]_{1}^{2}$$
#
# $$E(X^2) = 2.743 - 0.086$$
#
# $$E(X^2) = 2.657$$
#
# $$Var(X) = E(X^2) - (E(X))^2$$
#
# $$Var(X) = 2.657 - (1.607^2)$$
#
# $$Var(X) = 0.075$$
#
# $$\sigma = \sqrt{0.075}$$
#
# $$\sigma = 0.273$$
#
# -----
# c)
#
# $$f(x) = \frac{3x^2}{7}$$
#
# $$F(x) = \frac{x^3}{7}$$
#
# -----
# d)
#
# $$\frac{x^3}{7} = 0.5$$
#
# $$x^3 = 3.5$$
#
# $$x = 1.52$$
#
# $$median = 1.52$$
