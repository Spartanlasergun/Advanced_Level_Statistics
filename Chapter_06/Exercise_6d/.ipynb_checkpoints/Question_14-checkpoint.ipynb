# %% [markdown]
# # Question 14
# -----

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 8.1, 0.1)
y = []
for item in x:
    fx = 1 * item
    y.append(fx)

y_1 = [8, 8]
x_1 = [8, 9]

plt.plot(x, y)
plt.plot(x_1, y_1)
plt.show()

# %% [markdown]
# b)
#
# $$\int_{0}^{8} kx \ dx + \int_{8}^{9} 8k \ dx = 1$$
#
# $$[\frac{kx^2}{2}]_{0}^{8} + [8kx]_{8}^{9} = 1$$
#
# $$32k + (72k - 64k) = 1$$
#
# $$40k = 1$$
#
# $$k = 0.025$$
#
# -----
# c)
#
# $$F(x) = 0.0125x^2, \ \ \ for, \ \ 0 \le x \le 8$$
#
# $$F(x) = 0.2x, \ \ \ for, \ \ 8 \le x \le 9$$
#
# -----
# d)
#
# $$P(X \le 6) = \int_{0}^{6} 0.025x \ dx$$
#
# $$P(X \le 6) = [0.0125x^2]_{0}^{6}$$
#
# $$P(X \le 6) = 0.45$$
#
# Hence,
#
# $$P(X > 6) = 1 - 0.45 = 0.55$$
