# %% [markdown]
# # Question 2

# %%
mean = 16
median = 20
std = 5
skewness = (3 * (mean - median)) / std
print("The pearsons coefficient of skewness is = " + str(skewness))
# Out:
# The pearsons coefficient of skewness is = -2.4

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate skewed right normal distribution data
mu = 16  # Mean
sigma = 5  # Standard deviation
skewness = -2.4  # Skewness parameter (positive for right skew)
size = 1000  # Number of data points

data = np.random.normal(mu, sigma, size)
data = np.exp(data * skewness)  # Apply right skewness transformation

plt.plot(x, y, color='red', linewidth=2)

plt.xlabel('X')
plt.ylabel('Probability Density')
plt.title('Skewed Right Normal Distribution')
plt.grid(True)
plt.show()
