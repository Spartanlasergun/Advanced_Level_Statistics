# %% [markdown]
# # Question 4
# -----

# %% [markdown]
# | Time | Number of Children |
# | --- | --- |
# | 10-19 | 8 |
# | 20-24 | 15 |
# | 25-29 | 25 |
# | 30-39 | 18 |
# | 40-49 | 12 |
# | 50-64 | 7 |
# | 65-89 | 5 |

# %%
import matplotlib.pyplot as plt

x = [8, 15, 25, 18, 12, 7, 5]
midpoints = [14.5, 22, 27, 34.5, 44.5, 57, 77] 
data = []
index = 0
for item in x:
    count = item
    while count != 0:
        data.append(midpoints[index])
        count = count - 1
    index = index + 1

plt.hist(data, bins=[0, 10, 20, 25, 30, 40, 50, 65, 89], density=True, edgecolor="black")
plt.show()

# %%
print("(b) The distribution is positively skewed")
# Out:
# (b) The distribution is positively skewed
