# %% [markdown]
# # Quesiton 4
# -----

# %%
import matplotlib.pyplot as plt

frequency = [21, 62, 55, 50, 12]
interval_midpoints = [45, 53, 58, 65, 73]
raw_data = []
index = 0
for item in frequency:
    count = item
    while count != 0:
        raw_data.append(interval_midpoints[index])
        count = count - 1
    index = index + 1

plt.hist(raw_data, bins=[40.5, 50.5, 55.5, 60.5, 70.5, 75.5], density=True, edgecolor="black")
# Out:
# (array([0.0105, 0.062 , 0.055 , 0.025 , 0.012 ]),
#  array([40.5, 50.5, 55.5, 60.5, 70.5, 75.5]),
#  <BarContainer object of 5 artists>)
