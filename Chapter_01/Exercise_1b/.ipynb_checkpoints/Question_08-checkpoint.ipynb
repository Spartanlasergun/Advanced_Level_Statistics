# %% [markdown]
# # Question 8
# -----

# %% [markdown]
# | Intervals | Frequencies |
# | --- | --- |
# | 0-2 | 1 |
# | 3-5 | 5 |
# | 6-8 | 6 |
# | 9-11 | 3 |
# | 12-14 | 5 |
# | 15-17 | 4 |

# %%
import matplotlib.pyplot as plt

raw_data = [15, 12, 8, 12, 3, 10, 14, 17, 5, 3, 8, 11,
           7, 16, 5, 13, 12, 11, 6, 7, 4, 17, 8, 1]


plt.hist(raw_data, bins=[0, 2.5, 5.5, 8.5, 11.5, 14.5, 17], density=True, edgecolor="black")
plt.show()
