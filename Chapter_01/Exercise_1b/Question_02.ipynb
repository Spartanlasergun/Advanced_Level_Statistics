# %%
import matplotlib.pyplot as plt
import pandas as pd
import stemgraphic
import csv
data = [86, 101, 114, 118, 87, 92, 93, 116,
       105, 102, 97, 93, 101, 111, 96, 117,
       100, 106, 118, 101, 107, 96, 101, 102,
       104, 92, 99, 107, 98, 105, 113, 100,
       103, 108, 92, 109, 95, 100, 103, 110,
       113, 99, 106, 116, 101, 105, 86, 88,
       108, 92]

headings = ["85-89", "90-94", "95-99", "100-104", "105-109", "110-114", "115-119"]
intervals = [85, 90, 95, 100, 105, 110, 115, 120]
count, bins, bars = plt.hist(data, bins=intervals, edgecolor="black")

csv_data = open("question_2_data.csv", 'w')
writer = csv.writer(csv_data)
writer.writerow(headings)
writer.writerow(count)
csv_data.close()


freq_dist = pd.read_csv("question_2_data.csv")
freq_dist.head()
# Out:
#    85-89  90-94  95-99  100-104  105-109  110-114  115-119
# 0    4.0    6.0    7.0     13.0     10.0      5.0      5.0

# %%
stemgraphic.stem_graphic(data, scale=10)
# Out:
# (<Figure size 750x175 with 1 Axes>, <Axes: >)
