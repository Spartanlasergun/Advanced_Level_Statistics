# %% [markdown]
# # Question 5
# -----

# %%
import stemgraphic
data = [7.0, 7.6, 12.5, 12.9, 8.3, 9.7, 8.4, 11.1,
       7.5, 7.5, 9.8, 10.4, 11.6, 11.3, 7.3, 7.8,
       6.8, 6.2, 6.1, 5.6, 5.6, 5.8, 4.8, 4.3,
       0.0, 0.6, 0.8, 1.6, 0.2, 2.4, 2.6]
stemgraphic.stem_graphic(data, scale=1)
# Out:
# (<Figure size 750x400 with 1 Axes>, <Axes: >)
