# %% [markdown]
# # Question 4
# -----

# %%
import stemgraphic
data = [9.2, 7.3, 7.0, 6.5, 5.4, 5.3, 10.1, 8.4,
       8.8, 7.1, 7.6, 7.9, 6.7, 9.6, 5.5, 7.4,
       7.0, 8.2, 5.5, 7.8, 8.2, 7.5, 6.1, 6.1,
       3.9, 6.8, 7.6, 8.1, 8.0, 10.0]
stemgraphic.stem_graphic(data, scale=1)
# Out:
# (<Figure size 750x275 with 1 Axes>, <Axes: >)
