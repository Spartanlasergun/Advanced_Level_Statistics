# %% [markdown]
# # Question 2
# -----

# %%
import stemgraphic
data = [32, 31, 26, 27, 27, 32, 29, 26, 25, 25, 29, 31, 32, 26, 30, 24, 32, 27, 26, 31]
stemgraphic.stem_graphic(data, scale=1)
# Out:
# (<Figure size 750x300 with 1 Axes>, <Axes: >)
