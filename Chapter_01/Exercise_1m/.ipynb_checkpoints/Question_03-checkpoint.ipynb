# %% [markdown]
# # Question Three

# %%
import seaborn as sns

data = [51, 45, 31, 43, 97, 16, 18, 23, 34, 35, 35,
        85, 62, 20, 22, 51, 57, 49, 22, 18, 27]

sns.boxplot(x=data)
# Out:
# <Axes: >

# %% [markdown]
# Based on the plot, the only outlier is the number 97.
