# %% [markdown]
# # Question Ten

# %% [markdown]
# gradient, m = -0.2
#
# hence,
#
# $$ 3 = c + (0)(-0.2) $$
#
# $$ c = 3 $$
#
# The regression function is given by
#
# $$ y= 3 - 0.2x $$
#
# hence,
#
# $$ -0.2x = 3 - y $$
#
# $$ 0.2x = y - 3 $$
#
# $$ x = 5y - 15 $$

# %%
import matplotlib.pyplot as plt

x = list(range(0, 100, 1))
y = []
for item in x:
    func = (5 * item) - 15
    y.append(func)

plt.plot(x, y)
plt.show()
