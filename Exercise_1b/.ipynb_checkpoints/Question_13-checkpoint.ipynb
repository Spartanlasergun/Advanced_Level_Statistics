# %%
import matplotlib.pyplot as plt

midpoints = [74.5, 124.5, 174.5, 224.5, 274.5]
lucy_freq = [6, 14, 10, 6, 4]
jack_freq = [2, 6, 10, 16, 6]

plt.plot(midpoints, lucy_freq)
plt.plot(midpoints, jack_freq)
