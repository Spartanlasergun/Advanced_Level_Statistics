# %% [markdown]
# # Question 4
# -----

# %%
import numpy as np

x = [7, 12, 13, 17, 23, 25, 30, 20]
y = [23, 22, 18, 15, 7, 13, 8, 27]

pearsons = np.corrcoef(x, y)[0, 1]
print(pearsons)
# Out:
# -0.6902326046107593

# %%
from scipy.integrate import quad
import math
import numpy as np
from scipy.special import gamma

class T_dist:
    def __init__(self, nu):
        self.nu = nu
        numerator = gamma((nu + 1) / 2)
        denominator = np.sqrt(np.pi * nu) * gamma(nu / 2)
        self.coefficient = numerator / denominator

    def t_distribution_pdf(self, x):
        return self.coefficient * ((1 + (x**2 / self.nu))**(-(self.nu + 1) / 2))

    def integrate(self, lower_limit, upper_limit):
        result, error = quad(self.t_distribution_pdf, lower_limit, upper_limit)
        
        return result

    def locate(self, area):
        fx = 0
        x = -6
        while fx < area:
            fx = self.integrate(-6, x)
            x = x + 0.00001
            
        return x

# %%
r = pearsons
n = 8
nu = n - 2
t = (r * (math.sqrt(nu))) / math.sqrt((1 - (r**2)))
t_dist = T_dist(nu)
prob = t_dist.integrate(-100, t)
print("a)")
print(prob)
if prob > 0.05:
    print("do not reject the null")
else:
    print("reject the null")
# Out:
# a)
# 0.029057720776593927
# reject the null

# %%
import matplotlib.pyplot as plt

plt.scatter(x, y)
plt.show()

# %% [markdown]
# For part (a) , the scatter diagram does reinforce the conclusion

# %%
x = [5.1, 5.4, 5.5, 10, 10.2, 10.4, 15, 15.4, 15.6, 30, 20.2]
y = [5.3, 10.2, 15.7, 5, 10.9, 15.1, 5.3, 10.9, 15.3, 25.1, 20]
pearsons = np.corrcoef(x, y)[0, 1]
print(pearsons)
# Out:
# 0.6857744453378904

# %%
r = pearsons
n = 11
nu = n - 2
t = (r * (math.sqrt(nu))) / math.sqrt((1 - (r**2)))
t_dist = T_dist(nu)
prob = t_dist.integrate(-100, t)
print("b)")
print(prob)
if prob < 0.99:
    print("do not reject the null")
else:
    print("reject the null")
# Out:
# b)
# 0.9900857829317425
# reject the null

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# For part (b), the scatter diagram does reinforce the conclusion
