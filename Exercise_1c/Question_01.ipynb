# %%
import matplotlib.pyplot as plt
import math

categories = ["Bus", "Car", "Bicycle", "Walking"]
data = [12, 2, 5, 9]


plt.pie(data, labels=categories, startangle=90, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x20d30326f50>,
# ...
#  [Text(-1.0724207066739067, 0.24477301300804977, 'Bus'),
#   Text(-0.24477298790623175, -1.0724207124032321, 'Car'),
#   Text(0.5852353402263547, -0.9313965839266016, 'Bicycle'),
#   Text(0.9313965839266016, 0.5852353402263547, 'Walking')],
#  [Text(-0.5849567490948581, 0.13351255254984531, '42.9%'),
#   Text(-0.13351253885794456, -0.5849567522199447, '7.1%'),
#   Text(0.3192192764871025, -0.5080345003236009, '17.9%'),
#   Text(0.5080345003236009, 0.3192192764871025, '32.1%')])

# %%
Bus_angle = 0.429 * 360
Car_angle = 0.071 * 360
Bicycle_angle = 0.179 * 360
Walking_angle = 0.321 * 360
angles = [Bus_angle, Car_angle, Bicycle_angle, Walking_angle]
print(angles)
# Out:
# [154.44, 25.56, 64.44, 115.56]

# %%
r_1 = 5
F_1 = 28
F_2 = 34

r_2 = ((math.sqrt(F_2)) / (math.sqrt(F_1))) * r_1
r_2 = round(r_2, 3)
print(str(r_2) + "cm")
# Out:
# 5.51cm
