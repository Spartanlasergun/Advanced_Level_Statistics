# %%
import stemgraphic
data = [74, 52, 67, 68, 71, 76, 86, 81, 73, 68, 64, 75, 71, 61, 63, 57, 67, 57, 59, 72, 79, 64, 70, 74, 77, 79, 65, 68, 76, 83]
stemgraphic.stem_graphic(data, scale=10)
# Out:
# (<Figure size 750x175 with 1 Axes>, <Axes: >)

# %%
from collections import Counter
mode_list = Counter(data)
mode = mode_list.most_common(1)
print("The mode of the data is: " +  str(mode[0][0]))
# Out:
# The mode of the data is: 68
