# %%
import stemgraphic
data = [0.14, 0.17, 0.21, 0.20, 0.20, 0.22, 0.14, 0.24, 0.26, 0.17, 0.14, 0.17, 0.21, 0.20, 0.22, 0.14, 0.24, 0.26,
       0.17, 0.18, 0.17, 0.21, 0.20, 0.23, 0.17, 0.23, 0.21, 0.23, 0.24, 0.23]
stemgraphic.stem_graphic(data, scale=0.01)
# Out:
# (<Figure size 750x400 with 1 Axes>, <Axes: >)
